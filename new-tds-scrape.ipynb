# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import random
import time
from helper_functions import *
import csv

# %%
urls = {
    'Towards Data Science': 'https://towardsdatascience.com/archive/{0}/{1:02d}/{2:02d}'
}

# %%
selected_days = random.sample([i for i in range(1, 366)], 50)

# %%
selected_days
# Out:
# [347,
#  86,
#  259,
#  220,
#  193,
#  287,
#  233,
#  82,
#  28,
#  256,
#  313,
#  68,
#  46,
#  126,
#  156,
#  42,
#  306,
#  258,
#  312,
#  279,
#  121,
#  105,
#  27,
#  138,
#  60,
#  45,
#  151,
#  133,
#  33,
#  357,
#  51,
#  160,
#  216,
#  261,
#  178,
#  342,
#  129,
#  71,
#  348,
#  88,
#  346,
#  326,
#  364,
#  169,
#  304,
#  132,
#  80,
#  331,
#  41,
#  292]

# %%
medium_df = pd.DataFrame(data, columns=[
    'id', 'url', 'title', 'subtitle',
    'n_sections', 'n_paragraphs', 'section_titles', 'story_text',
    'claps', 'responses',
    'reading_time', 'publication', 'date','year'])

# %%
#Create file for output
cols=['url', 'title', 'subtitle',
    'n_sections', 'n_paragraphs', 'section_titles', 'story_text',
    'claps', 'responses',
    'reading_time', 'publication', 'date','year']

#with open("articles_50_per_year.csv", mode="w") as file:
#    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#    writer.writerow(cols)
                    
#file.close()

# %%
data = []
article_id = 0
years = [2022]
i = 0
n = len(selected_days)
for year in years:
    for d in selected_days:
        i += 1
        month, day = convert_day(d)
        date = '{0}-{1:02d}-{2:02d}'.format(year, month, day)
        print(f'{i} / {n} ; {date}')
        for publication, url in urls.items():
            rand_sleep() #sleep random number of seconds
            response = requests.get(url.format(year, month, day), allow_redirects=True)
            if not response.url.startswith(url.format(year, month, day)):
                continue
            page = response.content
            soup = BeautifulSoup(page, 'html.parser')
            articles = soup.find_all(
                "div",
                class_="postArticle postArticle--short js-postArticle js-trackPostPresentation js-trackPostScrolls")
            for article in articles:
                title = article.find("h3", class_="graf--title")
                if title is None:
                    continue
                title = title.contents[0]
                article_id += 1
                subtitle = article.find("h4", class_="graf--subtitle")
                subtitle = subtitle.contents[0] if subtitle is not None else ''
                #image = article.find("img", class_="graf-image")
                #image = '' if image is None else get_img(image['src'], 'images', f'{article_id}')
                article_url = article.find_all("a")[3]['href'].split('?')[0]
                number_sections, number_paragraphs, section_titles, story_text = get_article_text(article_url)
                buttons = article.find_all("button")
                claps = get_claps(buttons[1].contents[0]) if len(buttons) > 0 else None
                reading_time = article.find("span", class_="readingTime")
                reading_time = 0 if reading_time is None else int(reading_time['title'].split(' ')[0])
                responses = article.find_all("a")
                if len(responses) == 7:
                    responses = responses[6].contents[0].split(' ')
                    if len(responses) == 0:
                        responses = 0
                    else:
                        responses = responses[0]
                else:
                    responses = 0

                info = [article_url, title, subtitle,\
                             number_sections, number_paragraphs, section_titles, story_text,\
                             claps, responses,\
                             reading_time, publication, date,year]
                
                with open("articles_50_per_year.csv", mode="a") as file:
                    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    writer.writerow(info)
                    
                file.close()
# Out:
# 1 / 50 ; 2022-12-13
# 2 / 50 ; 2022-03-27
# 3 / 50 ; 2022-09-16
# 4 / 50 ; 2022-08-08
# 5 / 50 ; 2022-07-12
# 6 / 50 ; 2022-10-14
# 7 / 50 ; 2022-08-21
# 8 / 50 ; 2022-03-23
# 9 / 50 ; 2022-01-28
# 10 / 50 ; 2022-09-13
# 11 / 50 ; 2022-11-09
# 12 / 50 ; 2022-03-09
# 13 / 50 ; 2022-02-15
# 14 / 50 ; 2022-05-06
# 15 / 50 ; 2022-06-05
# 16 / 50 ; 2022-02-11
# 17 / 50 ; 2022-11-02
# 18 / 50 ; 2022-09-15
# 19 / 50 ; 2022-11-08
# 20 / 50 ; 2022-10-06
# 21 / 50 ; 2022-05-01
# 22 / 50 ; 2022-04-15
# 23 / 50 ; 2022-01-27
# 24 / 50 ; 2022-05-18
# 25 / 50 ; 2022-03-01
# 26 / 50 ; 2022-02-14
# 27 / 50 ; 2022-05-31
# 28 / 50 ; 2022-05-13
# 29 / 50 ; 2022-02-02
# 30 / 50 ; 2022-12-23
# 31 / 50 ; 2022-02-20
# 32 / 50 ; 2022-06-09
# 33 / 50 ; 2022-08-04
# 34 / 50 ; 2022-09-18
# 35 / 50 ; 2022-06-27
# 36 / 50 ; 2022-12-08
# 37 / 50 ; 2022-05-09
# 38 / 50 ; 2022-03-12
# 39 / 50 ; 2022-12-14
# 40 / 50 ; 2022-03-29
# 41 / 50 ; 2022-12-12
# 42 / 50 ; 2022-11-22
# 43 / 50 ; 2022-12-30
# 44 / 50 ; 2022-06-18
# 45 / 50 ; 2022-10-31
# 46 / 50 ; 2022-05-12
# 47 / 50 ; 2022-03-21
# 48 / 50 ; 2022-11-27
# 49 / 50 ; 2022-02-10
# 50 / 50 ; 2022-10-19

# %%
names = ["Alice", "Bob", "Charlie"]
with open("example.txt", mode="w") as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    #file.write(", ".join(names))
    writer.writerow(names)
    writer.writerow(names)
file.close()

# %%
data = pd.read_csv("example.txt")
data
# Out:
#       id                                                url  \
# 0      1  https://towardsdatascience.com/6-things-we-all...
# 1      2  https://towardsdatascience.com/statistical-sig...
# 2      3  https://towardsdatascience.com/dealing-with-im...
# 3      4  https://towardsdatascience.com/family-fun-with...
# 4      5  https://towardsdatascience.com/16-useful-advic...
# ..   ...                                                ...
# 136  137  https://towardsdatascience.com/speech-to-text-...
# 137  138  https://towardsdatascience.com/ai-single-cell-...
# 138  139  https://towardsdatascience.com/python-set-diff...
# 139  140  https://towardsdatascience.com/whats-in-a-tupl...
# 140  141  https://towardsdatascience.com/using-local-imp...
#
#                                                  title  \
# 0    6 lessons we all need to learn from Machine Le...
# 1                   Statistical Significance Explained
# 2    Dealing with Imbalanced Classes in Machine Lea...
# 3    Family fun with deepfakes. Or how I got my wif...
# 4       16 Useful Advices for Aspiring Data Scientists
# ..                                                 ...
# 136  How to Perform Speech-To-Text and Remove PII w...
# 137  AI, single cell genomics, and the new era of c...
# 138  Python Set Difference — A Complete Beginner Guide
# 139                        What’s in a Tuple? — Part 2
# 140  Using Random Forests to Help Explain Why MLB P...
#
#                                               subtitle  n_sections  \
# 0                                                  NaN           1
# 1                                                  NaN           1
# 2                                                  NaN           1
# 3                                                  NaN           1
# 4                                                  NaN           1
# ..                                                 ...         ...
# 136      Removing Personally Identifiable Information…           1
# 137                                                NaN           1
# 138      What is Python Set Difference? What does the…           7
# 139  Now that you’ve learned about tuples in Python...           1
# 140                       How local importance scores…           4
#
#      n_paragraphs                                     section_titles  \
# 0              32  ['6 lessons we all need to learn from Machine ...
# 1              25             ['Statistical Significance Explained']
# 2               9  ['Dealing with Imbalanced Classes in Machine L...
# 3              24  ['Family fun with deepfakes. Or how I got my w...
# 4              54  ['16 Useful Advices for Aspiring Data Scientis...
# ..            ...                                                ...
# 136            28  ['How to Perform Speech-To-Text and Remove PII...
# 137             5  ['AI, single cell genomics, and the new era of...
# 138            43  ['Python Set Difference — A Complete Beginner ...
# 139            11                    ['What’s in a Tuple? — Part 2']
# 140            26  ['Using Random Forests to Help Explain Why MLB...
#
#                                             story_text   claps  responses  \
# 0    Machine learning (ML) as a field has been arou...   167.0          3
# 1    What does it mean to prove something with data...  7100.0         51
# 2    Most real-world classification problems displa...  9500.0         16
# 3    [ Update 3 Feb 2018: added two new creations a...  9800.0         32
# 4    Why is data science sexy? It has something to ...  3200.0          9
# ..                                                 ...     ...        ...
# 136  In a couple of my recent articles I discussed ...    73.0          0
# 137  Editor’s note: The TDS Podcast is hosted by Je...     NaN          0
# 138  In the last week’s article, you’ve learned in ...    58.0          1
# 139  This is a follow-up to my earlier article, Wha...    18.0          0
# 140  Last fall I wrote an article titled: Rfviz: An...    28.0          0
#
#      reading_time           publication        date  year
# 0               3  Towards Data Science  2017-02-02  2017
# 1              10  Towards Data Science  2018-02-02  2018
# 2               5  Towards Data Science  2018-02-02  2018
# 3               5  Towards Data Science  2018-02-02  2018
# 4              21  Towards Data Science  2018-02-02  2018
# ..            ...                   ...         ...   ...
# 136             5  Towards Data Science  2022-02-02  2022
# 137             3  Towards Data Science  2022-02-02  2022
# 138             6  Towards Data Science  2022-02-02  2022
# 139             3  Towards Data Science  2022-02-02  2022
# 140             8  Towards Data Science  2022-02-02  2022
#
# [141 rows x 14 columns]

# %%
selected_days[33:49]
# Out:
# [261, 178, 342, 129, 71, 348, 88, 346, 326, 364, 169, 304, 132, 80, 331, 41]
